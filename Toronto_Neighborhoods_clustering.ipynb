# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True
# %config IPCompleter.use_jedi=False

# %%
toronto_df = pd.read_csv('/Users/marphiil/Downloads/PROYECTO-FINAL-main/data/toronto_poscode_coord.csv')
print(toronto_df.shape)
toronto_df.head()
# Out:
# (103, 5)
#   PostalCode           Borough                                Neighbourhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    latitude  longitude
# 0  43.75245  -79.32991
# 1  43.73057  -79.31306
# 2  43.65512  -79.36264
# 3  43.72327  -79.45042
# 4  43.66253  -79.39188

# %%
print('The dataframe has {} boroughs and {} postal codes.'.format(
        len(toronto_df['Borough'].unique()),
        toronto_df.shape[0]))
# Out:
# The dataframe has 10 boroughs and 103 postal codes.

# %%
# !pip install geopy
from geopy.geocoders import Nominatim
import folium
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 457 kB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent = 'toronto_explorer')

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10.5)

for lat, lng, borough, neighborhood in zip(toronto_df['latitude'], toronto_df['longitude'], toronto_df['Borough'], toronto_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='g',
        fill_opacity= 1,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bbe1b23f46f14083bee02d98bc367c14%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bbe1b23f46f14083bee02d98bc367c14%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bbe1b23f46f14083bee02d98bc367c14%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bbe1b23f46f14083bee02d98bc367c14%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
boroughs_df = toronto_df[(toronto_df['Borough']=='Central Toronto') | (toronto_df['Borough']=='Downtown Toronto') | (toronto_df['Borough']=='West Toronto') | (toronto_df['Borough']=='East Toronto')].reset_index(drop=True)
print(boroughs_df.shape)
boroughs_df.head()
# Out:
# (39, 5)
#   PostalCode           Borough                                Neighbourhood  \
# 0        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2        M5B  Downtown Toronto                     Garden District, Ryerson
# 3        M5C  Downtown Toronto                               St. James Town
# 4        M4E      East Toronto                                  The Beaches
#
#    latitude  longitude
# 0  43.65512  -79.36264
# 1  43.66253  -79.39188
# 2  43.65739  -79.37804
# 3  43.65215  -79.37587
# 4  43.67709  -79.29547

# %%
boroughs_df['Neighbourhood'] = boroughs_df['Neighbourhood'].apply(lambda x: x.split(',')[0])

boroughs_df
# Out:
#    PostalCode           Borough                          Neighbourhood  \
# 0         M5A  Downtown Toronto                            Regent Park
# 1         M7A  Downtown Toronto                           Queen's Park
# 2         M5B  Downtown Toronto                        Garden District
# 3         M5C  Downtown Toronto                         St. James Town
# 4         M4E      East Toronto                            The Beaches
# 5         M5E  Downtown Toronto                            Berczy Park
# 6         M5G  Downtown Toronto                     Central Bay Street
# 7         M6G  Downtown Toronto                               Christie
# 8         M5H  Downtown Toronto                               Richmond
# 9         M6H      West Toronto                               Dufferin
# 10        M5J  Downtown Toronto                      Harbourfront East
# 11        M6J      West Toronto                        Little Portugal
# 12        M4K      East Toronto                      The Danforth West
# 13        M5K  Downtown Toronto                Toronto Dominion Centre
# 14        M6K      West Toronto                               Brockton
# 15        M4L      East Toronto                           India Bazaar
# 16        M5L  Downtown Toronto                         Commerce Court
# 17        M4M      East Toronto                        Studio District
# 18        M4N   Central Toronto                          Lawrence Park
# 19        M5N   Central Toronto                               Roselawn
# 20        M4P   Central Toronto                       Davisville North
# 21        M5P   Central Toronto               Forest Hill North & West
# 22        M6P      West Toronto                              High Park
# 23        M4R   Central Toronto                     North Toronto West
# 24        M5R   Central Toronto                              The Annex
# 25        M6R      West Toronto                               Parkdale
# 26        M4S   Central Toronto                             Davisville
# 27        M5S  Downtown Toronto                  University of Toronto
# 28        M6S      West Toronto                              Runnymede
# 29        M4T   Central Toronto                             Moore Park
# 30        M5T  Downtown Toronto                      Kensington Market
# 31        M4V   Central Toronto                        Summerhill West
# 32        M5V  Downtown Toronto                               CN Tower
# 33        M4W  Downtown Toronto                               Rosedale
# 34        M5W  Downtown Toronto                         Stn A PO Boxes
# 35        M4X  Downtown Toronto                         St. James Town
# 36        M5X  Downtown Toronto                   First Canadian Place
# 37        M4Y  Downtown Toronto                   Church and Wellesley
# 38        M7Y      East Toronto  Business reply mail Processing Centre
#
#     latitude  longitude
# 0   43.65512  -79.36264
# 1   43.66253  -79.39188
# 2   43.65739  -79.37804
# 3   43.65215  -79.37587
# 4   43.67709  -79.29547
# 5   43.64536  -79.37306
# 6   43.65609  -79.38493
# 7   43.66869  -79.42071
# 8   43.64970  -79.38258
# 9   43.66505  -79.43891
# 10  43.64285  -79.38076
# 11  43.64848  -79.41774
# 12  43.68375  -79.35512
# 13  43.64710  -79.38153
# 14  43.63941  -79.42676
# 15  43.66797  -79.31467
# 16  43.64840  -79.37914
# 17  43.66213  -79.33497
# 18  43.72843  -79.38713
# 19  43.71208  -79.41848
# 20  43.71276  -79.38851
# 21  43.69479  -79.41440
# 22  43.65973  -79.46281
# 23  43.71458  -79.40668
# 24  43.67484  -79.40452
# 25  43.64777  -79.44989
# 26  43.70340  -79.38659
# 27  43.66311  -79.40180
# 28  43.64982  -79.47548
# 29  43.69048  -79.38318
# 30  43.65351  -79.39722
# 31  43.68568  -79.40237
# 32  43.64082  -79.39818
# 33  43.68190  -79.37829
# 34  43.64869  -79.38544
# 35  43.66788  -79.36649
# 36  43.64828  -79.38146
# 37  43.66659  -79.38133
# 38  43.64869  -79.38544

# %%
address = 'Central Toronto, Toronto'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.65238435, -79.38356765.

# %%
map_Boroughs = folium.Map(location = [latitude, longitude], zoom_start = 12)

for lat, lng, borough, neighborhood in zip(boroughs_df['latitude'], boroughs_df['longitude'], boroughs_df['Borough'], boroughs_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
    [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='g',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Boroughs)
map_Boroughs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4feeb2e3611d4d728a4a3f99cfbc7113%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4feeb2e3611d4d728a4a3f99cfbc7113%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4feeb2e3611d4d728a4a3f99cfbc7113%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4feeb2e3611d4d728a4a3f99cfbc7113%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.65238435%2C%20-79.38356765%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
CLIENT_ID = 'LSN2P0PGLDYFXGK3O4S0DJ3BIN5JF4TQOKNDTXSZPNCSGHMQ' 
CLIENT_SECRET = 'DH5JJ5G40UOBHRWBWOREZELDOT021MVAAR5GRG0UBAGYYGDX' 
VERSION = '20210601' 
LIMIT = 100

# %%
boroughs_df.head(1)
# Out:
#   PostalCode           Borough Neighbourhood  latitude  longitude
# 0        M5A  Downtown Toronto   Regent Park  43.65512  -79.36264

# %%
neighborhood_lat = boroughs_df.loc[0, 'latitude']
neighborhood_lng = boroughs_df.loc[0, 'longitude']
neighborhood_name = boroughs_df.loc[0, 'Neighbourhood']

print('The coordinate values of {} are\n- latitude: {},\n- longitude: {}.'.format(neighborhood_name, 
                                                               neighborhood_lat, 
                                                               neighborhood_lng))
# Out:
# The coordinate values of Regent Park are
# - latitude: 43.65512000000007,
# - longitude: -79.36263999999994.

# %%
LIMIT = 100
RADIUS = 750

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        neighborhood_lat, 
        neighborhood_lng,
        RADIUS,
        LIMIT)

# %%
import requests

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60d1649bf0fad0315a25365c'},
#  'response': {'headerLocation': 'Corktown',
#   'headerFullLocation': 'Corktown, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 77,
#   'suggestedBounds': {'ne': {'lat': 43.66187000675007,
#     'lng': -79.35332786684909},
#    'sw': {'lat': 43.648369993250064, 'lng': -79.3719521331508}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b8466a498e83df908c3f21',
#        'name': 'Tandem Coffee',
#        'location': {'address': '368 King St E',
#         'crossStreet': 'at Trinity St',
#         'lat': 43.65355870959944,
#         'lng': -79.36180945913513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65355870959944,
#           'lng': -79.36180945913513}],
#         'distance': 186,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['368 King St E (at Trinity St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53b8466a498e83df908c3f21-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54ea41ad498e9a11e9e13308',
#        'name': 'Roselle Desserts',
#        'location': {'address': '362 King St E',
#         'crossStreet': 'Trinity St',
#         'lat': 43.653446723052674,
#         'lng': -79.3620167174383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653446723052674,
#           'lng': -79.3620167174383}],
#         'distance': 192,
#         'postalCode': 'M5A 1K9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['362 King St E (Trinity St)',
#          'Toronto ON M5A 1K9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54ea41ad498e9a11e9e13308-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51853a73498e4d97a8b20831',
#        'name': 'Rooster Coffee',
#        'location': {'address': '343 King St E',
#         'crossStreet': 'btwn Princess & Berkeley St',
#         'lat': 43.65189965670432,
#         'lng': -79.36560912104514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65189965670432,
#           'lng': -79.36560912104514}],
#         'distance': 430,
#         'postalCode': 'M5A 1L1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['343 King St E (btwn Princess & Berkeley St)',
#          'Toronto ON M5A 1L1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51853a73498e4d97a8b20831-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ade8ea8f964a5205a7621e3',
#        'name': 'Berkeley Church',
#        'location': {'address': '315 Queen St E',
#         'crossStreet': 'at Berkeley St',
#         'lat': 43.65512324174501,
#         'lng': -79.36587330410705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65512324174501,
#           'lng': -79.36587330410705}],
#         'distance': 260,
#         'postalCode': 'M5A 1S7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['315 Queen St E (at Berkeley St)',
#          'Toronto ON M5A 1S7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'shortName': 'Event Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ade8ea8f964a5205a7621e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5619551a498e9e35fce2256b',
#        'name': 'Sumach Espresso',
#        'location': {'address': '118 Sumach St',
#         'crossStreet': 'at Shuter St',
#         'lat': 43.65813540553308,
#         'lng': -79.35951549011845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65813540553308,
#           'lng': -79.35951549011845}],
#         'distance': 419,
#         'postalCode': 'M5A 3J9',
#         'cc': 'CA',
#         'neighborhood': 'Downtown Toronto',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['118 Sumach St (at Shuter St)',
#          'Toronto ON M5A 3J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5619551a498e9e35fce2256b-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc39c914cdfc9b6f29c9721',
#        'name': 'Souvlaki Express',
#        'location': {'address': '348 Queen street east',
#         'crossStreet': 'at Parliament St',
#         'lat': 43.65558391537734,
#         'lng': -79.36443816909016,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65558391537734,
#           'lng': -79.36443816909016}],
#         'distance': 153,
#         'postalCode': 'M5A 1T1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['348 Queen street east (at Parliament St)',
#          'Toronto ON M5A 1T1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc39c914cdfc9b6f29c9721-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad776eef964a520e20a21e3',
#        'name': 'Mangia and Bevi Resto-Bar',
#        'location': {'address': '260 King St E',
#         'crossStreet': 'Princess',
#         'lat': 43.652249517927686,
#         'lng': -79.36635530500347,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.652249517927686,
#           'lng': -79.36635530500347}],
#         'distance': 437,
#         'postalCode': 'M5R 4L5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['260 King St E (Princess)',
#          'Toronto ON M5R 4L5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad776eef964a520e20a21e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50760559e4b0e8c7babe2497',
#        'name': 'Body Blitz Spa East',
#        'location': {'address': '497 King Street East',
#         'crossStreet': 'btwn Sackville St and Sumach St',
#         'lat': 43.65473505045365,
#         'lng': -79.35987433132891,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65473505045365,
#           'lng': -79.35987433132891}],
#         'distance': 226,
#         'postalCode': 'M5A 1L9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['497 King Street East (btwn Sackville St and Sumach St)',
#          'Toronto ON M5A 1L9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50760559e4b0e8c7babe2497-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af59046f964a520e0f921e3',
#        'name': 'Figs Breakfast & Lunch',
#        'location': {'address': '344 Queen St. E.',
#         'crossStreet': 'at Parliament St.',
#         'lat': 43.65567455427388,
#         'lng': -79.3645032892494,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65567455427388,
#           'lng': -79.3645032892494}],
#         'distance': 162,
#         'postalCode': 'M5A 1S8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['344 Queen St. E. (at Parliament St.)',
#          'Toronto ON M5A 1S8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af59046f964a520e0f921e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada57aff964a520972121e3',
#        'name': 'Sukhothai',
#        'location': {'address': '274 Parliament St',
#         'crossStreet': 'btwn Coatsworth St. & Shuter St.',
#         'lat': 43.658444465539525,
#         'lng': -79.36568085121628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.658444465539525,
#           'lng': -79.36568085121628}],
#         'distance': 443,
#         'postalCode': 'M5A 2Z6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['274 Parliament St (btwn Coatsworth St. & Shuter St.)',
#          'Toronto ON M5A 2Z6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada57aff964a520972121e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5612b1cc498e3dd742af0dc8',
#        'name': 'Impact Kitchen',
#        'location': {'address': '573 King St E',
#         'crossStreet': 'at St Lawrence St',
#         'lat': 43.65636850543279,
#         'lng': -79.35697968750694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65636850543279,
#           'lng': -79.35697968750694}],
#         'distance': 476,
#         'postalCode': 'M5A 4L3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['573 King St E (at St Lawrence St)',
#          'Toronto ON M5A 4L3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5612b1cc498e3dd742af0dc8-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3e1eaa6faac9b66dc60d76',
#        'name': 'Distillery Sunday Market',
#        'location': {'address': '1 Trinity St',
#         'lat': 43.650074989330655,
#         'lng': -79.36183171318665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650074989330655,
#           'lng': -79.36183171318665}],
#         'distance': 565,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Trinity St', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3e1eaa6faac9b66dc60d76-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57cd9d20498e6ab8342980e2',
#        'name': 'Arvo',
#        'location': {'address': '17 Gristmill Ln',
#         'crossStreet': 'at Parliament St',
#         'lat': 43.64996280366945,
#         'lng': -79.36144178325522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64996280366945,
#           'lng': -79.36144178325522}],
#         'distance': 582,
#         'postalCode': 'M5A 3R6',
#         'cc': 'CA',
#         'neighborhood': 'Distillery',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['17 Gristmill Ln (at Parliament St)',
#          'Toronto ON M5A 3R6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57cd9d20498e6ab8342980e2-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a520bff620e3',
#        'name': 'The Distillery Historic District',
#        'location': {'address': 'btwn Front, Cherry, Gardiner & Parliament',
#         'lat': 43.65024435658077,
#         'lng': -79.35932278633118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65024435658077,
#           'lng': -79.35932278633118}],
#         'distance': 604,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['btwn Front, Cherry, Gardiner & Parliament',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ef964a520bff620e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd8630535aad13a4bb890f3',
#        'name': 'Subway',
#        'location': {'address': '344 Queen Street East, Unit 1',
#         'lat': 43.65570120830647,
#         'lng': -79.36464396270765,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65570120830647,
#           'lng': -79.36464396270765}],
#         'distance': 173,
#         'postalCode': 'M5A 1S8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['344 Queen Street East, Unit 1',
#          'Toronto ON M5A 1S8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd8630535aad13a4bb890f3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574c229e498ebb5c6b257902',
#        'name': 'Cooper Koo Family YMCA',
#        'location': {'address': '461 Cherry St',
#         'lat': 43.65324910177244,
#         'lng': -79.35800826343677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65324910177244,
#           'lng': -79.35800826343677}],
#         'distance': 427,
#         'postalCode': 'M5A 0H7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['461 Cherry St', 'Toronto ON M5A 0H7', 'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a37',
#          'name': 'Distribution Center',
#          'pluralName': 'Distribution Centers',
#          'shortName': 'Distributor',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574c229e498ebb5c6b257902-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0978e1f964a520cd1723e3',
#        'name': 'SOMA chocolatemaker',
#        'location': {'address': '55 Mill Street, Unit #48',
#         'crossStreet': 'The Distillery District',
#         'lat': 43.65062222570758,
#         'lng': -79.35812684032683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65062222570758,
#           'lng': -79.35812684032683}],
#         'distance': 618,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Mill Street, Unit #48 (The Distillery District)',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0978e1f964a520cd1723e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fad7eb3e4b0b0320d241fa4',
#        'name': 'LCBO',
#        'location': {'address': '222 Front St. E',
#         'crossStreet': 'at Parliament St',
#         'lat': 43.65098233828489,
#         'lng': -79.36536081685296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65098233828489,
#           'lng': -79.36536081685296}],
#         'distance': 510,
#         'postalCode': 'M5A 1E7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['222 Front St. E (at Parliament St)',
#          'Toronto ON M5A 1E7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fad7eb3e4b0b0320d241fa4-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c16a548955976b0cadea4f6',
#        'name': 'Parliament Square Park',
#        'location': {'address': '44 Parliament Street',
#         'lat': 43.65026388338689,
#         'lng': -79.36219509081177,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65026388338689,
#           'lng': -79.36219509081177}],
#         'distance': 541,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['44 Parliament Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c16a548955976b0cadea4f6-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c7fbf7424f9373e6427e99',
#        'name': 'Starbucks',
#        'location': {'address': '351 King St E, 60',
#         'lat': 43.651613,
#         'lng': -79.364917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651613,
#           'lng': -79.364917}],
#         'distance': 431,
#         'postalCode': 'M5A 1L1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['351 King St E, 60',
#          'Toronto ON M5A 1L1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58c7fbf7424f9373e6427e99-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5092fe87e4b0476c6e7375e2',
#        'name': 'Regent Park Aquatic Centre',
#        'location': {'address': '640 Dundas St. East',
#         'crossStreet': 'at Sumach St.',
#         'lat': 43.6606003130796,
#         'lng': -79.36139162915349,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6606003130796,
#           'lng': -79.36139162915349}],
#         'distance': 618,
#         'postalCode': 'M5A 2B8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['640 Dundas St. East (at Sumach St.)',
#          'Toronto ON M5A 2B8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5092fe87e4b0476c6e7375e2-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbdc6784495721ea262617a',
#        'name': "Fusaro's",
#        'location': {'address': '294 Richmond St. E.',
#         'lat': 43.65334679826618,
#         'lng': -79.36951731755141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65334679826618,
#           'lng': -79.36951731755141}],
#         'distance': 588,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['294 Richmond St. E.', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbdc6784495721ea262617a-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57e0745a498ea809dbf75f68',
#        'name': 'Souk Tabule',
#        'location': {'address': '494 Front St E',
#         'crossStreet': 'at Bayview',
#         'lat': 43.65375556880743,
#         'lng': -79.35439006096168,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65375556880743,
#           'lng': -79.35439006096168}],
#         'distance': 681,
#         'cc': 'CA',
#         'neighborhood': 'Canary District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['494 Front St E (at Bayview)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57e0745a498ea809dbf75f68-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5653a96f498e99c91027730b',
#        'name': 'Cacao 70',
#        'location': {'address': '28 Gristmill Lane',
#         'lat': 43.650066694561666,
#         'lng': -79.36072263183006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650066694561666,
#           'lng': -79.36072263183006}],
#         'distance': 583,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['28 Gristmill Lane',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5653a96f498e99c91027730b-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddfbaca185035f3a44e8df6',
#        'name': 'Underpass Park',
#        'location': {'address': 'Eastern Ave.',
#         'crossStreet': 'Richmond St.',
#         'lat': 43.65576361726024,
#         'lng': -79.3548059463501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65576361726024,
#           'lng': -79.3548059463501}],
#         'distance': 635,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Eastern Ave. (Richmond St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ddfbaca185035f3a44e8df6-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561ffc99498e1468dac63cdd',
#        'name': 'Schnitzel Queen',
#        'location': {'address': '211 Queen E',
#         'crossStreet': 'King And Sherbourne',
#         'lat': 43.65423906004429,
#         'lng': -79.37053284604036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65423906004429,
#           'lng': -79.37053284604036}],
#         'distance': 643,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['211 Queen E (King And Sherbourne)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'shortName': 'German',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561ffc99498e1468dac63cdd-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5022a0cde4b0c3bc4aff8d5c',
#        'name': 'The Black Canary Espresso Bar',
#        'location': {'address': '61 Sherbourne St.',
#         'lat': 43.651868733003134,
#         'lng': -79.36850642387674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651868733003134,
#           'lng': -79.36850642387674}],
#         'distance': 595,
#         'postalCode': 'M5A 2P8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['61 Sherbourne St.',
#          'Toronto ON M5A 2P8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5022a0cde4b0c3bc4aff8d5c-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb680ed1344b713b8a09d04',
#        'name': 'Berkeley Street Theatre',
#        'location': {'address': '26 Berkeley St.',
#         'crossStreet': 'btwn Front St. E & The Esplanade',
#         'lat': 43.65051724574011,
#         'lng': -79.36417258802608,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65051724574011,
#           'lng': -79.36417258802608}],
#         'distance': 527,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['26 Berkeley St. (btwn Front St. E & The Esplanade)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb680ed1344b713b8a09d04-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55be4bd4498e08d9ccc061e4',
#        'name': 'NEO COFFEE BAR',
#        'location': {'address': '161 Frederick St, Unit 100',
#         'crossStreet': 'at King St E',
#         'lat': 43.65070234158804,
#         'lng': -79.36925939681731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65070234158804,
#           'lng': -79.36925939681731}],
#         'distance': 725,
#         'postalCode': 'M5A 4P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['161 Frederick St, Unit 100 (at King St E)',
#          'Toronto ON M5A 4P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55be4bd4498e08d9ccc061e4-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb68165f562ef3b88483097',
#        'name': 'Young Centre for the Performing Arts',
#        'location': {'address': '50 Tank House Ln.',
#         'crossStreet': 'at Cherry St.',
#         'lat': 43.65082466432163,
#         'lng': -79.35759324240415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65082466432163,
#           'lng': -79.35759324240415}],
#         'distance': 627,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['50 Tank House Ln. (at Cherry St.)',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb68165f562ef3b88483097-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b156a02f964a5207fac23e3',
#        'name': 'Brick Street Bakery',
#        'location': {'address': '27 Trinity St',
#         'crossStreet': 'in Distillery District',
#         'lat': 43.650574039683974,
#         'lng': -79.35953942981405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650574039683974,
#           'lng': -79.35953942981405}],
#         'distance': 564,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['27 Trinity St (in Distillery District)',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b156a02f964a5207fac23e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adb58f7f964a520412621e3',
#        'name': "Balzac's Coffee",
#        'location': {'address': '1 Trinity Street',
#         'crossStreet': 'at Distillery Ln.',
#         'lat': 43.649797141476185,
#         'lng': -79.35914199644303,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649797141476185,
#           'lng': -79.35914199644303}],
#         'distance': 656,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Trinity Street (at Distillery Ln.)',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adb58f7f964a520412621e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b7ccd5e1f8ed6002c9bd7d0',
#        'name': 'The Aviary',
#        'location': {'lat': 43.65363394725125,
#         'lng': -79.35466212072043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65363394725125,
#           'lng': -79.35466212072043}],
#         'distance': 663,
#         'postalCode': 'M5A 1H7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON M5A 1H7', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b7ccd5e1f8ed6002c9bd7d0-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d84d98181fdb1f7d4a704c0',
#        'name': 'Caffe Furbo',
#        'location': {'address': '12 case goods lane',
#         'lat': 43.649969882303814,
#         'lng': -79.35884946388191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649969882303814,
#           'lng': -79.35884946388191}],
#         'distance': 649,
#         'postalCode': 'M5A 3C4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['12 case goods lane',
#          'Toronto ON M5A 3C4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '47611149'}},
#       'referralId': 'e-0-4d84d98181fdb1f7d4a704c0-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ccc048498ec7792efc955e',
#        'name': 'Corktown Common',
#        'location': {'lat': 43.655617799749734,
#         'lng': -79.3562113397429,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.655617799749734,
#           'lng': -79.3562113397429}],
#         'distance': 520,
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51ccc048498ec7792efc955e-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d8dff7498eb4e5e661e78d',
#        'name': 'Ardo',
#        'location': {'address': '243 King St E',
#         'crossStreet': 'at Lower Sherbourne St',
#         'lat': 43.6512011278776,
#         'lng': -79.36835027595798,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6512011278776,
#           'lng': -79.36835027595798}],
#         'distance': 633,
#         'postalCode': 'M5A 1J9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['243 King St E (at Lower Sherbourne St)',
#          'Toronto ON M5A 1J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d8dff7498eb4e5e661e78d-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc8c0bbd338236a7cc49e7c',
#        'name': 'St Lawrence Community Centre Pool',
#        'location': {'address': '230 The Esplanade',
#         'crossStreet': 'Sherbourne',
#         'lat': 43.64955698056156,
#         'lng': -79.36506251486433,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64955698056156,
#           'lng': -79.36506251486433}],
#         'distance': 649,
#         'postalCode': 'M5A 4J6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['230 The Esplanade (Sherbourne)',
#          'Toronto ON M5A 4J6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc8c0bbd338236a7cc49e7c-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56423155498e78e89181cb44',
#        'name': 'Cluck Clucks',
#        'location': {'address': '222 The Esplanade',
#         'crossStreet': 'Princess',
#         'lat': 43.64964842651325,
#         'lng': -79.3664078057654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64964842651325,
#           'lng': -79.3664078057654}],
#         'distance': 680,
#         'postalCode': 'M5A 4M8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['222 The Esplanade (Princess)',
#          'Toronto ON M5A 4M8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56423155498e78e89181cb44-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b64d531f964a52090d32ae3',
#        'name': 'On The Rocks',
#        'location': {'address': '169 Front Street East',
#         'crossStreet': 'at Sherbourne St',
#         'lat': 43.65040844699981,
#         'lng': -79.3683544809487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65040844699981,
#           'lng': -79.3683544809487}],
#         'distance': 697,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['169 Front Street East (at Sherbourne St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d120941735',
#          'name': 'Karaoke Bar',
#          'pluralName': 'Karaoke Bars',
#          'shortName': 'Karaoke',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b64d531f964a52090d32ae3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566e1294498e3f6629006bc3',
#        'name': 'Dominion Pub and Kitchen',
#        'location': {'address': '500 Queen Street East',
#         'lat': 43.65691857501867,
#         'lng': -79.35896684476664,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65691857501867,
#           'lng': -79.35896684476664}],
#         'distance': 357,
#         'postalCode': 'M5A 1T9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['500 Queen Street East',
#          'Toronto ON M5A 1T9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
# ...
#        'name': 'Subway',
#        'location': {'address': '200 Kings St E',
#         'lat': 43.651306519617535,
#         'lng': -79.37020859374229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651306519617535,
#           'lng': -79.37020859374229}],
#         'distance': 742,
#         'postalCode': 'M5A 3W8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200 Kings St E',
#          'Toronto ON M5A 3W8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bccbcd468f976b0822d6383-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae9c117f964a52019b621e3',
#        'name': 'cafe 260',
#        'location': {'address': '260 Richmond St East',
#         'crossStreet': 'Sherbourne',
#         'lat': 43.653183236880515,
#         'lng': -79.37011452592975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653183236880515,
#           'lng': -79.37011452592975}],
#         'distance': 639,
#         'postalCode': 'M5A 1P4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['260 Richmond St East (Sherbourne)',
#          'Toronto ON M5A 1P4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57512678'}},
#       'referralId': 'e-0-4ae9c117f964a52019b621e3-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52af6dc5498e33995b0bbf03',
#        'name': 'Sultan Of Samosas',
#        'location': {'address': '1 Oak Street',
#         'lat': 43.66022749787444,
#         'lng': -79.36622571571063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66022749787444,
#           'lng': -79.36622571571063}],
#         'distance': 637,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Oak Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52af6dc5498e33995b0bbf03-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6e0c605f68b93a075d0bc1',
#        'name': 'Tim Hortons',
#        'location': {'address': '69 Regent Park Blvd',
#         'crossStreet': 'at Dundas St E',
#         'lat': 43.659935,
#         'lng': -79.3613063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.659935,
#           'lng': -79.3613063}],
#         'distance': 546,
#         'postalCode': 'M5A 0K7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['69 Regent Park Blvd (at Dundas St E)',
#          'Toronto ON M5A 0K7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6e0c605f68b93a075d0bc1-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54d37e23498e5e29bcb35362',
#        'name': 'ODIN Cafe + Bar',
#        'location': {'address': '514 King St E',
#         'crossStreet': 'at River St',
#         'lat': 43.656738544928054,
#         'lng': -79.35650305267754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.656738544928054,
#           'lng': -79.35650305267754}],
#         'distance': 526,
#         'postalCode': 'M5A 1M1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['514 King St E (at River St)',
#          'Toronto ON M5A 1M1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54d37e23498e5e29bcb35362-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1e9904f964a520501c24e3',
#        'name': 'Dollarama',
#        'location': {'address': '149 Sherbourne St',
#         'crossStreet': 'at Shuter',
#         'lat': 43.655316,
#         'lng': -79.369756,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.655316,
#           'lng': -79.369756}],
#         'distance': 573,
#         'postalCode': 'M5A 2R5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['149 Sherbourne St (at Shuter)',
#          'Toronto ON M5A 2R5',
#          'Canada']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1e9904f964a520501c24e3-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bca9a2e0687ef3b3e78dccc',
#        'name': 'Tim Hortons',
#        'location': {'address': '335 Parliament St',
#         'crossStreet': 'Dundas st e',
#         'lat': 43.6599728,
#         'lng': -79.3659513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6599728,
#           'lng': -79.3659513}],
#         'distance': 602,
#         'postalCode': 'M5A 2Z3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['335 Parliament St (Dundas st e)',
#          'Toronto ON M5A 2Z3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bca9a2e0687ef3b3e78dccc-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5292543a498ec4d4c99c0c64',
#        'name': 'The Healthy Road',
#        'location': {'address': '518 King Street East',
#         'crossStreet': 'Sumach',
#         'lat': 43.656264585886454,
#         'lng': -79.35711882680904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.656264585886454,
#           'lng': -79.35711882680904}],
#         'distance': 462,
#         'postalCode': 'M5A 1M1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['518 King Street East (Sumach)',
#          'Toronto ON M5A 1M1',
#          'Canada']},
#        'categories': [{'id': '50aa9e744b90af0d42d5de0e',
#          'name': 'Health Food Store',
#          'pluralName': 'Health Food Stores',
#          'shortName': 'Health Food Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5292543a498ec4d4c99c0c64-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '6043da90c2a0d03a5423b27f',
#        'name': 'Nava Social',
#        'location': {'address': '514 King St. East',
#         'lat': 43.656678,
#         'lng': -79.356516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.656678,
#           'lng': -79.356516}],
#         'distance': 522,
#         'postalCode': 'M5A 1M1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['514 King St. East',
#          'Toronto ON M5A 1M1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1367343896'}},
#       'referralId': 'e-0-6043da90c2a0d03a5423b27f-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbc6a0f76ad9c7460ebe7cb',
#        'name': 'FreshCo',
#        'location': {'address': '325 Parliament St',
#         'crossStreet': 'at Dundas St',
#         'lat': 43.65955158801718,
#         'lng': -79.36585713164392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65955158801718,
#           'lng': -79.36585713164392}],
#         'distance': 557,
#         'postalCode': 'M5A 2Z3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['325 Parliament St (at Dundas St)',
#          'Toronto ON M5A 2Z3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbc6a0f76ad9c7460ebe7cb-72'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7db1d7d598a09327d8c362',
#        'name': 'John Innes Community Centre',
#        'location': {'address': '150 sherbourne street',
#         'lat': 43.65562484597637,
#         'lng': -79.36986088427695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65562484597637,
#           'lng': -79.36986088427695}],
#         'distance': 584,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['150 sherbourne street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7db1d7d598a09327d8c362-73'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57dd8bcd498e8eec19b9c896',
#        'name': 'FUEL+',
#        'location': {'address': '469 Front St',
#         'crossStreet': 'Rolling Mills Rd',
#         'lat': 43.653193,
#         'lng': -79.355867,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653193,
#           'lng': -79.355867}],
#         'distance': 586,
#         'postalCode': 'M5A',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['469 Front St (Rolling Mills Rd)',
#          'Toronto ON M5A',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57dd8bcd498e8eec19b9c896-74'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '579cc5f2498e0fe8397deebb',
#        'name': 'GW General',
#        'location': {'lat': 43.650495,
#         'lng': -79.357538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650495,
#           'lng': -79.357538}],
#         'distance': 658,
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'shortName': 'Antiques',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-579cc5f2498e0fe8397deebb-75'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5766f6df498edaf26cf1d010',
#        'name': 'Distillery Streetcar Loop',
#        'location': {'address': 'Cherry Street',
#         'crossStreet': 'Mill Street',
#         'lat': 43.650677,
#         'lng': -79.35649,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650677,
#           'lng': -79.35649}],
#         'distance': 699,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Cherry Street (Mill Street)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b51',
#          'name': 'Tram Station',
#          'pluralName': 'Tram Stations',
#          'shortName': 'Tram',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5766f6df498edaf26cf1d010-76'}]}]}}

# %%
import json
from pandas import json_normalize

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
nearby_venues.head(2)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-53b8466a498e83df908c3f21-0              0
# 1  e-0-54ea41ad498e9a11e9e13308-1              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id        venue.name venue.location.address  \
# 0  53b8466a498e83df908c3f21     Tandem Coffee          368 King St E
# 1  54ea41ad498e9a11e9e13308  Roselle Desserts          362 King St E
#
#   venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0              at Trinity St           43.653559          -79.361809
# 1                 Trinity St           43.653447          -79.362017
#
#                        venue.location.labeledLatLngs  ...  \
# 0  [{'label': 'display', 'lat': 43.65355870959944...  ...
# 1  [{'label': 'display', 'lat': 43.65344672305267...  ...
#
#    venue.location.city venue.location.state venue.location.country  \
# 0              Toronto                   ON                 Canada
# 1              Toronto                   ON                 Canada
#
#                      venue.location.formattedAddress  \
# 0  [368 King St E (at Trinity St), Toronto ON, Ca...
# 1  [362 King St E (Trinity St), Toronto ON M5A 1K...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...                  0
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...                  0
#
#   venue.photos.groups  venue.location.postalCode venue.location.neighborhood  \
# 0                  []                        NaN                         NaN
# 1                  []                    M5A 1K9                         NaN
#
#   venue.venuePage.id
# 0                NaN
# 1                NaN
#
# [2 rows x 22 columns]

# %%
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
nearby_venues.head(2)
# Out:
#          venue.name                                   venue.categories  \
# 0     Tandem Coffee  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1  Roselle Desserts  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
#
#    venue.location.lat  venue.location.lng
# 0           43.653559          -79.361809
# 1           43.653447          -79.362017

# %%
nearby_venues['venue.categories'] = nearby_venues['venue.categories'].apply(lambda x: x[0]['name'])

# %%
nearby_venues.head()
# Out:
#          venue.name venue.categories  venue.location.lat  venue.location.lng
# 0     Tandem Coffee      Coffee Shop           43.653559          -79.361809
# 1  Roselle Desserts           Bakery           43.653447          -79.362017
# 2    Rooster Coffee      Coffee Shop           43.651900          -79.365609
# 3   Berkeley Church      Event Space           43.655123          -79.365873
# 4   Sumach Espresso      Coffee Shop           43.658135          -79.359515

# %%
def get_nearby_venues(neighborhoods, latitudes, longitudes):
    
    LIMIT = 100
    RADIUS = 1000
    
    venues_list = []
    
    for neighborhood, lat, lng in zip(neighborhoods, latitudes, longitudes):
        print(neighborhood)         
       
        url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
                CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION, 
                lat, 
                lng,
                RADIUS,
                LIMIT)
        
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        venues_list.append([(neighborhood, 
                            lat, 
                            lng,  
                            v['venue']['name'],
                            v['venue']['location']['lat'],
                            v['venue']['location']['lng'],
                            v['venue']['categories'][0]['name']) for v in results])
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])    
    nearby_venues.columns = ['Neighborhood', 
          'Neighborhood Latitude', 
          'Neighborhood Longitude', 
          'Venue', 
          'Venue Latitude', 
          'Venue Longitude', 
          'Venue Category']
    
    return(nearby_venues)

# %%
boroughs_venues = get_nearby_venues(boroughs_df['Neighbourhood'], 
                                   boroughs_df['latitude'], 
                                   boroughs_df['longitude'])
# Out:
# Regent Park
# Queen's Park
# Garden District
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond
# Dufferin
# Harbourfront East
# Little Portugal
# The Danforth West
# Toronto Dominion Centre
# Brockton
# India Bazaar
# Commerce Court
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park
# North Toronto West
# The Annex
# Parkdale
# Davisville
# University of Toronto
# Runnymede
# Moore Park
# Kensington Market
# Summerhill West
# CN Tower
# Rosedale
# Stn A PO Boxes
# St. James Town
# First Canadian Place
# Church and Wellesley
# Business reply mail Processing Centre

# %%
print(boroughs_venues.shape)
boroughs_venues.to_csv('/Users/marphiil/Downloads/PROYECTO-FINAL-main/data/boroughs_venues.csv', index=False)
boroughs_venues.head()
# Out:
# (3230, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park               43.65512               -79.36264
# 1  Regent Park               43.65512               -79.36264
# 2  Regent Park               43.65512               -79.36264
# 3  Regent Park               43.65512               -79.36264
# 4  Regent Park               43.65512               -79.36264
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0              Tandem Coffee       43.653559       -79.361809
# 1           Roselle Desserts       43.653447       -79.362017
# 2             Rooster Coffee       43.651900       -79.365609
# 3            Sumach Espresso       43.658135       -79.359515
# 4  Mangia and Bevi Resto-Bar       43.652250       -79.366355
#
#        Venue Category
# 0         Coffee Shop
# 1              Bakery
# 2         Coffee Shop
# 3         Coffee Shop
# 4  Italian Restaurant

# %%
boroughs_venues.groupby(by = 'Neighborhood').count().sort_values(by = 'Venue', ascending = False)
# Out:
#                                        Neighborhood Latitude  \
# Neighborhood
# St. James Town                                           138
# Berczy Park                                              100
# Garden District                                          100
# Toronto Dominion Centre                                  100
# The Annex                                                100
# Stn A PO Boxes                                           100
# Richmond                                                 100
# Queen's Park                                             100
# Brockton                                                 100
# Kensington Market                                        100
# Harbourfront East                                        100
# Little Portugal                                          100
# Church and Wellesley                                     100
# Commerce Court                                           100
# Business reply mail Processing Centre                    100
# CN Tower                                                 100
# Central Bay Street                                       100
# Christie                                                 100
# First Canadian Place                                     100
# University of Toronto                                    100
# Davisville                                               100
# The Danforth West                                         98
# Regent Park                                               96
# Studio District                                           95
# Davisville North                                          94
# High Park                                                 90
# Dufferin                                                  87
# Parkdale                                                  84
# The Beaches                                               71
# Summerhill West                                           70
# India Bazaar                                              69
# Runnymede                                                 67
# Moore Park                                                53
# North Toronto West                                        50
# Forest Hill North & West                                  37
# Rosedale                                                  12
# Lawrence Park                                             11
# Roselawn                                                   8
#
#                                        Neighborhood Longitude  Venue  \
# Neighborhood
# St. James Town                                            138    138
# Berczy Park                                               100    100
# Garden District                                           100    100
# Toronto Dominion Centre                                   100    100
# The Annex                                                 100    100
# Stn A PO Boxes                                            100    100
# Richmond                                                  100    100
# Queen's Park                                              100    100
# Brockton                                                  100    100
# Kensington Market                                         100    100
# Harbourfront East                                         100    100
# Little Portugal                                           100    100
# Church and Wellesley                                      100    100
# Commerce Court                                            100    100
# Business reply mail Processing Centre                     100    100
# CN Tower                                                  100    100
# Central Bay Street                                        100    100
# Christie                                                  100    100
# First Canadian Place                                      100    100
# University of Toronto                                     100    100
# Davisville                                                100    100
# The Danforth West                                          98     98
# Regent Park                                                96     96
# Studio District                                            95     95
# Davisville North                                           94     94
# High Park                                                  90     90
# Dufferin                                                   87     87
# Parkdale                                                   84     84
# The Beaches                                                71     71
# Summerhill West                                            70     70
# India Bazaar                                               69     69
# Runnymede                                                  67     67
# Moore Park                                                 53     53
# North Toronto West                                         50     50
# Forest Hill North & West                                   37     37
# Rosedale                                                   12     12
# Lawrence Park                                              11     11
# Roselawn                                                    8      8
#
#                                        Venue Latitude  Venue Longitude  \
# Neighborhood
# St. James Town                                    138              138
# Berczy Park                                       100              100
# Garden District                                   100              100
# Toronto Dominion Centre                           100              100
# The Annex                                         100              100
# Stn A PO Boxes                                    100              100
# Richmond                                          100              100
# Queen's Park                                      100              100
# Brockton                                          100              100
# Kensington Market                                 100              100
# Harbourfront East                                 100              100
# Little Portugal                                   100              100
# Church and Wellesley                              100              100
# Commerce Court                                    100              100
# Business reply mail Processing Centre             100              100
# CN Tower                                          100              100
# Central Bay Street                                100              100
# Christie                                          100              100
# First Canadian Place                              100              100
# University of Toronto                             100              100
# Davisville                                        100              100
# The Danforth West                                  98               98
# Regent Park                                        96               96
# Studio District                                    95               95
# Davisville North                                   94               94
# High Park                                          90               90
# Dufferin                                           87               87
# Parkdale                                           84               84
# The Beaches                                        71               71
# Summerhill West                                    70               70
# India Bazaar                                       69               69
# Runnymede                                          67               67
# Moore Park                                         53               53
# North Toronto West                                 50               50
# Forest Hill North & West                           37               37
# Rosedale                                           12               12
# Lawrence Park                                      11               11
# Roselawn                                            8                8
#
#                                        Venue Category
# Neighborhood
# St. James Town                                    138
# Berczy Park                                       100
# Garden District                                   100
# Toronto Dominion Centre                           100
# The Annex                                         100
# Stn A PO Boxes                                    100
# Richmond                                          100
# Queen's Park                                      100
# Brockton                                          100
# Kensington Market                                 100
# Harbourfront East                                 100
# Little Portugal                                   100
# Church and Wellesley                              100
# Commerce Court                                    100
# Business reply mail Processing Centre             100
# CN Tower                                          100
# Central Bay Street                                100
# Christie                                          100
# First Canadian Place                              100
# University of Toronto                             100
# Davisville                                        100
# The Danforth West                                  98
# Regent Park                                        96
# Studio District                                    95
# Davisville North                                   94
# High Park                                          90
# Dufferin                                           87
# Parkdale                                           84
# The Beaches                                        71
# Summerhill West                                    70
# India Bazaar                                       69
# Runnymede                                          67
# Moore Park                                         53
# North Toronto West                                 50
# Forest Hill North & West                           37
# Rosedale                                           12
# Lawrence Park                                      11
# Roselawn                                            8

# %%
print('There are {} unique venue categories.'.format(len(boroughs_venues['Venue Category'].unique())))
# Out:
# There are 260 unique venue categories.

# %%
boroughs_onehot = pd.get_dummies(boroughs_venues[['Venue Category']], prefix = '', prefix_sep = '')

boroughs_onehot['Neighborhood'] = boroughs_venues['Neighborhood']

# %%
len(boroughs_onehot.Neighborhood.unique())
# Out:
# 38

# %%
boroughs_grouped = boroughs_onehot.groupby(by='Neighborhood').mean().reset_index()
boroughs_grouped
# Out:
#                              Neighborhood  Accessories Store  Adult Boutique  \
# 0                             Berczy Park               0.00            0.00
# 1                                Brockton               0.01            0.00
# 2   Business reply mail Processing Centre               0.00            0.00
# 3                                CN Tower               0.00            0.00
# 4                      Central Bay Street               0.00            0.00
# 5                                Christie               0.00            0.00
# 6                    Church and Wellesley               0.00            0.01
# 7                          Commerce Court               0.00            0.00
# 8                              Davisville               0.00            0.00
# 9                        Davisville North               0.00            0.00
# 10                               Dufferin               0.00            0.00
# 11                   First Canadian Place               0.00            0.00
# 12               Forest Hill North & West               0.00            0.00
# 13                        Garden District               0.00            0.00
# 14                      Harbourfront East               0.00            0.00
# 15                              High Park               0.00            0.00
# 16                           India Bazaar               0.00            0.00
# 17                      Kensington Market               0.00            0.00
# 18                          Lawrence Park               0.00            0.00
# 19                        Little Portugal               0.00            0.00
# 20                             Moore Park               0.00            0.00
# 21                     North Toronto West               0.00            0.00
# 22                               Parkdale               0.00            0.00
# 23                           Queen's Park               0.00            0.01
# 24                            Regent Park               0.00            0.00
# 25                               Richmond               0.00            0.00
# 26                               Rosedale               0.00            0.00
# 27                               Roselawn               0.00            0.00
# 28                              Runnymede               0.00            0.00
# 29                         St. James Town               0.00            0.00
# 30                         Stn A PO Boxes               0.00            0.00
# 31                        Studio District               0.00            0.00
# 32                        Summerhill West               0.00            0.00
# 33                              The Annex               0.00            0.00
# 34                            The Beaches               0.00            0.00
# 35                      The Danforth West               0.00            0.00
# 36                Toronto Dominion Centre               0.00            0.00
# 37                  University of Toronto               0.00            0.00
#
#     African Restaurant  American Restaurant  Amphitheater  Animal Shelter  \
# 0             0.000000             0.010000      0.000000        0.000000
# 1             0.000000             0.010000      0.000000        0.000000
# 2             0.000000             0.010000      0.000000        0.000000
# 3             0.000000             0.010000      0.000000        0.000000
# 4             0.000000             0.010000      0.000000        0.000000
# 5             0.000000             0.010000      0.000000        0.000000
# 6             0.000000             0.010000      0.000000        0.000000
# 7             0.000000             0.010000      0.000000        0.000000
# 8             0.000000             0.010000      0.000000        0.000000
# 9             0.000000             0.000000      0.000000        0.000000
# 10            0.022989             0.000000      0.000000        0.000000
# 11            0.000000             0.010000      0.000000        0.000000
# 12            0.000000             0.000000      0.000000        0.000000
# 13            0.000000             0.010000      0.000000        0.000000
# 14            0.000000             0.010000      0.000000        0.000000
# 15            0.000000             0.000000      0.000000        0.000000
# 16            0.000000             0.000000      0.000000        0.000000
# 17            0.000000             0.000000      0.000000        0.000000
# 18            0.000000             0.000000      0.000000        0.000000
# 19            0.000000             0.020000      0.000000        0.000000
# 20            0.000000             0.018868      0.000000        0.000000
# 21            0.000000             0.000000      0.000000        0.000000
# 22            0.000000             0.023810      0.000000        0.000000
# 23            0.000000             0.000000      0.000000        0.000000
# 24            0.000000             0.000000      0.000000        0.010417
# 25            0.000000             0.010000      0.000000        0.000000
# 26            0.000000             0.000000      0.000000        0.000000
# 27            0.000000             0.000000      0.000000        0.000000
# 28            0.000000             0.000000      0.014925        0.000000
# 29            0.000000             0.014493      0.000000        0.000000
# 30            0.000000             0.010000      0.000000        0.000000
# 31            0.000000             0.031579      0.000000        0.000000
# 32            0.000000             0.014286      0.000000        0.000000
# 33            0.000000             0.010000      0.000000        0.000000
# 34            0.000000             0.000000      0.000000        0.000000
# 35            0.000000             0.010204      0.000000        0.000000
# 36            0.000000             0.010000      0.000000        0.000000
# 37            0.000000             0.000000      0.000000        0.000000
#
#     Antique Shop  Aquarium  Arcade  ...  Train Station  University  \
# 0       0.000000      0.00    0.00  ...           0.01        0.00
# 1       0.000000      0.00    0.00  ...           0.00        0.00
# 2       0.000000      0.00    0.00  ...           0.01        0.01
# 3       0.000000      0.01    0.00  ...           0.00        0.00
# 4       0.000000      0.00    0.00  ...           0.00        0.01
# 5       0.000000      0.00    0.00  ...           0.00        0.00
# 6       0.000000      0.00    0.00  ...           0.00        0.00
# 7       0.000000      0.00    0.00  ...           0.01        0.00
# 8       0.000000      0.00    0.00  ...           0.00        0.00
# 9       0.000000      0.00    0.00  ...           0.00        0.00
# 10      0.011494      0.00    0.00  ...           0.00        0.00
# 11      0.000000      0.00    0.00  ...           0.01        0.00
# 12      0.000000      0.00    0.00  ...           0.00        0.00
# 13      0.000000      0.00    0.00  ...           0.00        0.00
# 14      0.000000      0.02    0.00  ...           0.01        0.00
# 15      0.000000      0.00    0.00  ...           0.00        0.00
# 16      0.000000      0.00    0.00  ...           0.00        0.00
# 17      0.000000      0.00    0.00  ...           0.00        0.01
# 18      0.000000      0.00    0.00  ...           0.00        0.00
# 19      0.000000      0.00    0.01  ...           0.00        0.00
# 20      0.000000      0.00    0.00  ...           0.00        0.00
# 21      0.000000      0.00    0.00  ...           0.00        0.00
# 22      0.000000      0.00    0.00  ...           0.00        0.00
# 23      0.000000      0.00    0.00  ...           0.00        0.00
# 24      0.010417      0.00    0.00  ...           0.00        0.00
# 25      0.000000      0.00    0.00  ...           0.01        0.00
# 26      0.000000      0.00    0.00  ...           0.00        0.00
# 27      0.000000      0.00    0.00  ...           0.00        0.00
# 28      0.000000      0.00    0.00  ...           0.00        0.00
# 29      0.000000      0.00    0.00  ...           0.00        0.00
# 30      0.000000      0.00    0.00  ...           0.01        0.01
# 31      0.000000      0.00    0.00  ...           0.00        0.00
# 32      0.000000      0.00    0.00  ...           0.00        0.00
# 33      0.000000      0.00    0.00  ...           0.00        0.00
# 34      0.000000      0.00    0.00  ...           0.00        0.00
# 35      0.000000      0.00    0.00  ...           0.00        0.00
# 36      0.000000      0.01    0.00  ...           0.01        0.00
# 37      0.000000      0.00    0.00  ...           0.00        0.00
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Whisky Bar  \
# 0                        0.010000               0.000000        0.00
# 1                        0.020000               0.010000        0.00
# 2                        0.020000               0.000000        0.00
# 3                        0.000000               0.000000        0.00
# 4                        0.020000               0.000000        0.00
# 5                        0.020000               0.000000        0.00
# 6                        0.000000               0.000000        0.00
# 7                        0.020000               0.000000        0.00
# 8                        0.010000               0.000000        0.00
# 9                        0.010638               0.010638        0.00
# 10                       0.011494               0.011494        0.00
# 11                       0.020000               0.000000        0.00
# 12                       0.027027               0.000000        0.00
# 13                       0.010000               0.000000        0.00
# 14                       0.010000               0.000000        0.00
# 15                       0.000000               0.011111        0.00
# 16                       0.000000               0.000000        0.00
# 17                       0.040000               0.010000        0.00
# 18                       0.000000               0.000000        0.00
# 19                       0.040000               0.020000        0.01
# 20                       0.000000               0.018868        0.00
# 21                       0.000000               0.020000        0.00
# 22                       0.000000               0.000000        0.00
# 23                       0.010000               0.000000        0.00
# 24                       0.000000               0.000000        0.00
# 25                       0.020000               0.000000        0.00
# 26                       0.000000               0.000000        0.00
# 27                       0.000000               0.000000        0.00
# 28                       0.014925               0.000000        0.00
# 29                       0.014493               0.000000        0.00
# 30                       0.020000               0.000000        0.00
# 31                       0.000000               0.021053        0.00
# 32                       0.000000               0.014286        0.00
# 33                       0.030000               0.000000        0.00
# 34                       0.014085               0.000000        0.00
# 35                       0.000000               0.000000        0.00
# 36                       0.020000               0.000000        0.00
# 37                       0.040000               0.000000        0.00
#
#     Wine Bar  Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 0   0.000000       0.00         0.00           0.00     0.000000
# 1   0.000000       0.00         0.00           0.00     0.010000
# 2   0.000000       0.00         0.00           0.00     0.010000
# 3   0.000000       0.01         0.00           0.00     0.050000
# 4   0.000000       0.00         0.00           0.00     0.020000
# 5   0.000000       0.00         0.00           0.00     0.000000
# 6   0.000000       0.01         0.00           0.00     0.010000
# 7   0.000000       0.00         0.00           0.00     0.000000
# 8   0.000000       0.00         0.01           0.00     0.000000
# 9   0.010638       0.00         0.00           0.00     0.000000
# 10  0.000000       0.00         0.00           0.00     0.000000
# 11  0.000000       0.00         0.00           0.00     0.010000
# 12  0.000000       0.00         0.00           0.00     0.000000
# 13  0.000000       0.01         0.00           0.00     0.010000
# 14  0.000000       0.00         0.00           0.00     0.010000
# 15  0.000000       0.00         0.00           0.00     0.000000
# 16  0.000000       0.00         0.00           0.00     0.014493
# 17  0.010000       0.00         0.00           0.00     0.030000
# 18  0.000000       0.00         0.00           0.00     0.000000
# 19  0.020000       0.00         0.00           0.00     0.020000
# 20  0.000000       0.00         0.00           0.00     0.018868
# 21  0.020000       0.00         0.00           0.00     0.000000
# 22  0.000000       0.00         0.00           0.00     0.000000
# 23  0.000000       0.00         0.00           0.01     0.010000
# 24  0.000000       0.00         0.00           0.00     0.000000
# 25  0.000000       0.00         0.00           0.00     0.010000
# 26  0.000000       0.00         0.00           0.00     0.000000
# 27  0.000000       0.00         0.00           0.00     0.000000
# 28  0.000000       0.00         0.00           0.00     0.014925
# 29  0.000000       0.00         0.00           0.00     0.000000
# 30  0.000000       0.00         0.00           0.00     0.010000
# 31  0.000000       0.00         0.00           0.00     0.000000
# 32  0.000000       0.00         0.00           0.00     0.014286
# 33  0.010000       0.00         0.01           0.00     0.000000
# 34  0.000000       0.00         0.00           0.00     0.000000
# 35  0.000000       0.00         0.00           0.00     0.010204
# 36  0.000000       0.00         0.00           0.00     0.000000
# 37  0.000000       0.00         0.00           0.00     0.010000
#
# [38 rows x 260 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = boroughs_grouped['Neighborhood']

for ind in np.arange(boroughs_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(boroughs_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted.head()
# Out:
#                             Neighborhood 1st Most Common Venue  \
# 0                            Berczy Park           Coffee Shop
# 1                               Brockton                  Café
# 2  Business reply mail Processing Centre           Coffee Shop
# 3                               CN Tower           Coffee Shop
# 4                     Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café    Italian Restaurant            Restaurant
# 1           Coffee Shop                   Bar                Bakery
# 2                  Café            Restaurant                 Hotel
# 3                  Café                  Park           Yoga Studio
# 4   Japanese Restaurant                  Café      Sushi Restaurant
#
#   5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0   Japanese Restaurant                    Park          Cocktail Bar
# 1        Sandwich Place  Furniture / Home Store            Restaurant
# 2                   Gym     Japanese Restaurant             Gastropub
# 3  Gym / Fitness Center       French Restaurant                   Spa
# 4            Restaurant          Clothing Store                Bakery
#
#   8th Most Common Venue 9th Most Common Venue      10th Most Common Venue
# 0    Seafood Restaurant                   Gym                       Hotel
# 1    Italian Restaurant        Breakfast Spot                Cocktail Bar
# 2        Clothing Store            Shoe Store                Concert Hall
# 3                 Diner    Italian Restaurant                Dessert Shop
# 4                 Hotel                   Gym  Modern European Restaurant

# %%
neighborhoods_venues_sorted
# Out:
#                              Neighborhood 1st Most Common Venue  \
# 0                             Berczy Park           Coffee Shop
# 1                                Brockton                  Café
# 2   Business reply mail Processing Centre           Coffee Shop
# 3                                CN Tower           Coffee Shop
# 4                      Central Bay Street           Coffee Shop
# 5                                Christie     Korean Restaurant
# 6                    Church and Wellesley   Japanese Restaurant
# 7                          Commerce Court           Coffee Shop
# 8                              Davisville           Coffee Shop
# 9                        Davisville North           Coffee Shop
# 10                               Dufferin                   Bar
# 11                   First Canadian Place                  Café
# 12               Forest Hill North & West                  Park
# 13                        Garden District   Japanese Restaurant
# 14                      Harbourfront East                  Café
# 15                              High Park                   Bar
# 16                           India Bazaar     Indian Restaurant
# 17                      Kensington Market                  Café
# 18                          Lawrence Park                  Café
# 19                        Little Portugal                  Café
# 20                             Moore Park           Coffee Shop
# 21                     North Toronto West           Coffee Shop
# 22                               Parkdale           Coffee Shop
# 23                           Queen's Park           Coffee Shop
# 24                            Regent Park           Coffee Shop
# 25                               Richmond           Coffee Shop
# 26                               Rosedale                  Park
# 27                               Roselawn              Pharmacy
# 28                              Runnymede           Coffee Shop
# 29                         St. James Town                  Café
# 30                         Stn A PO Boxes           Coffee Shop
# 31                        Studio District           Coffee Shop
# 32                        Summerhill West           Coffee Shop
# 33                              The Annex           Coffee Shop
# 34                            The Beaches                   Pub
# 35                      The Danforth West      Greek Restaurant
# 36                Toronto Dominion Centre                  Café
# 37                  University of Toronto                  Café
#
#    2nd Most Common Venue          3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café             Italian Restaurant            Restaurant
# 1            Coffee Shop                            Bar                Bakery
# 2                   Café                     Restaurant                 Hotel
# 3                   Café                           Park           Yoga Studio
# 4    Japanese Restaurant                           Café      Sushi Restaurant
# 5            Coffee Shop                           Café         Grocery Store
# 6            Coffee Shop                           Park      Sushi Restaurant
# 7                   Café            Japanese Restaurant            Restaurant
# 8       Sushi Restaurant             Italian Restaurant           Pizza Place
# 9     Italian Restaurant                    Pizza Place                  Café
# 10                Bakery                    Coffee Shop                  Café
# 11           Coffee Shop                     Restaurant   Japanese Restaurant
# 12           Coffee Shop             Italian Restaurant                  Café
# 13           Coffee Shop                           Café      Sushi Restaurant
# 14           Coffee Shop                           Park            Restaurant
# 15                  Café                    Coffee Shop      Sushi Restaurant
# 16           Coffee Shop                           Park  Fast Food Restaurant
# 17           Coffee Shop  Vegetarian / Vegan Restaurant           Art Gallery
# 18                  Park                   College Quad             Bookstore
# 19    Italian Restaurant                    Pizza Place                Bakery
# 20         Grocery Store             Italian Restaurant                   Gym
# 21    Italian Restaurant            Sporting Goods Shop       Thai Restaurant
# 22                  Café                  Grocery Store      Sushi Restaurant
# 23      Sushi Restaurant            Japanese Restaurant                  Park
# 24            Restaurant                           Café                Bakery
# 25                  Café                     Restaurant   Japanese Restaurant
# 26                 Trail                     Playground           Candy Store
# 27            Playground                   Skating Rink      Asian Restaurant
# 28                  Café                            Pub           Pizza Place
# 29           Coffee Shop                     Restaurant   Japanese Restaurant
# 30                  Café                     Restaurant                 Hotel
# 31           Pizza Place                         Bakery  Fast Food Restaurant
# 32                  Café                           Park                  Bank
# 33    Italian Restaurant                           Café                   Gym
# 34           Coffee Shop                 Breakfast Spot          Burger Joint
# 35           Coffee Shop                           Café                  Bank
# 36   Japanese Restaurant                    Coffee Shop                 Hotel
# 37                Bakery  Vegetarian / Vegan Restaurant        Sandwich Place
#
#             5th Most Common Venue        6th Most Common Venue  \
# 0             Japanese Restaurant                         Park
# 1                  Sandwich Place       Furniture / Home Store
# 2                             Gym          Japanese Restaurant
# 3            Gym / Fitness Center            French Restaurant
# 4                      Restaurant               Clothing Store
# 5             Japanese Restaurant                          Pub
# 6        Mediterranean Restaurant                         Café
# 7                Sushi Restaurant                          Gym
# 8               Indian Restaurant                         Café
# 9                Sushi Restaurant         Fast Food Restaurant
# 10                           Park           Mexican Restaurant
# 11                            Gym                Deli / Bodega
# 12                       Pharmacy                         Bank
# 13                      Gastropub           Italian Restaurant
# 14                   Cocktail Bar                Deli / Bodega
# 15                            Gym                          Pub
# 16                            Pub                   Restaurant
# 17                    Yoga Studio          Arts & Crafts Store
# 18           Gym / Fitness Center                  Coffee Shop
# 19  Vegetarian / Vegan Restaurant             Asian Restaurant
# 20                           Park                  Pizza Place
# 21                            Gym                       Bakery
# 22                         Bakery  Eastern European Restaurant
# 23                           Café                   Restaurant
# 24             Italian Restaurant                   Beer Store
# 25                            Gym                        Hotel
# 26                  Grocery Store                 Optical Shop
# 27                          Trail                         Café
# 28              Food & Drink Shop             Sushi Restaurant
# 29             Italian Restaurant                       Bakery
# 30                            Gym          Japanese Restaurant
# 31                            Bar          American Restaurant
# 32                Thai Restaurant             Sushi Restaurant
# 33                 Sandwich Place                Grocery Store
# 34                         Bakery               Sandwich Place
# 35                            Pub           Italian Restaurant
# 36                     Restaurant                          Gym
# 37                    Coffee Shop                     Beer Bar
#
#    7th Most Common Venue 8th Most Common Venue    9th Most Common Venue  \
# 0           Cocktail Bar    Seafood Restaurant                      Gym
# 1             Restaurant    Italian Restaurant           Breakfast Spot
# 2              Gastropub        Clothing Store               Shoe Store
# 3                    Spa                 Diner       Italian Restaurant
# 4                 Bakery                 Hotel                      Gym
# 5                Theater  Caribbean Restaurant         Sushi Restaurant
# 6                  Diner            Restaurant           Clothing Store
# 7              Gastropub              Beer Bar             Cocktail Bar
# 8                 Bakery                  Bank               Restaurant
# 9        Thai Restaurant                 Diner              Supermarket
# 10    Italian Restaurant         Grocery Store                 Pharmacy
# 11      Sushi Restaurant          Cocktail Bar                    Hotel
# 12      Sushi Restaurant        Ice Cream Shop  Fruit & Vegetable Store
# 13            Restaurant        Sandwich Place                  Theater
# 14                 Hotel                   Gym      Japanese Restaurant
# 15                  Park         Grocery Store       Mexican Restaurant
# 16         Grocery Store        Sandwich Place            Burrito Place
# 17                Bakery                   Gym             Burger Joint
# 18                 Trail           College Gym                 Bus Line
# 19          Cocktail Bar           Coffee Shop               Restaurant
# 20                  Bank       Thai Restaurant               Bagel Shop
# 21                  Café                  Park               Restaurant
# 22       Thai Restaurant            Restaurant                 Pharmacy
# 23           Pizza Place             Bookstore     Gym / Fitness Center
# 24                   Pub                  Park            Grocery Store
# 25        Clothing Store      Sushi Restaurant                   Bakery
# 26          Noodle House             Nightclub  New American Restaurant
# 27                  Bank           Music Store             Music School
# 28                  Bank                Bakery       Italian Restaurant
# 29             Gastropub              Beer Bar            Deli / Bodega
# 30             Gastropub        Clothing Store               Shoe Store
# 31                 Diner    Italian Restaurant                     Café
# 32         Grocery Store    Italian Restaurant                      Gym
# 33                   Pub           Pizza Place                 Pharmacy
# 34                  Park       Thai Restaurant           Ice Cream Shop
# 35  Fast Food Restaurant        Ice Cream Shop                   Bakery
# 36                  Park         Deli / Bodega             Cocktail Bar
# 37            Restaurant       Thai Restaurant            Grocery Store
#
#         10th Most Common Venue
# 0                        Hotel
# 1                 Cocktail Bar
# 2                 Concert Hall
# 3                 Dessert Shop
# 4   Modern European Restaurant
# 5               Sandwich Place
# 6                    Gastropub
# 7           Seafood Restaurant
# 8                          Gym
# 9               Clothing Store
# 10                        Bank
# 11          Salon / Barbershop
# 12               Grocery Store
# 13                      Bakery
# 14            Sushi Restaurant
# 15             Thai Restaurant
# 16             Harbor / Marina
# 17            Sushi Restaurant
# 18                  Restaurant
# 19                         Bar
# 20                   Gastropub
# 21                  Playground
# 22                 Pizza Place
# 23              Sandwich Place
# 24             Thai Restaurant
# 25               Deli / Bodega
# 26                  Nail Salon
# 27                Optical Shop
# 28                         Gym
# 29                        Park
# 30                Concert Hall
# 31                        Bank
# 32        Gym / Fitness Center
# 33             Thai Restaurant
# 34        Caribbean Restaurant
# 35                     Theater
# 36            Sushi Restaurant
# 37                         Bar

# %%
from sklearn.cluster import KMeans

plt.style.use('ggplot')
Nc = range(1, 20)
kmeans = [kmeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(boroughs_grouped_clustering).score(boroughs_grouped_clustering) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-22a022736a9a> in <module>
#       3 plt.style.use('ggplot')
#       4 Nc = range(1, 20)
# ----> 5 kmeans = [kmeans(n_clusters=i) for i in Nc]
#       6 kmeans
#       7 score = [kmeans[i].fit(boroughs_grouped_clustering).score(boroughs_grouped_clustering) for i in range(len(kmeans))]
#
# <ipython-input-48-22a022736a9a> in <listcomp>(.0)
#       3 plt.style.use('ggplot')
#       4 Nc = range(1, 20)
# ----> 5 kmeans = [kmeans(n_clusters=i) for i in Nc]
#       6 kmeans
#       7 score = [kmeans[i].fit(boroughs_grouped_clustering).score(boroughs_grouped_clustering) for i in range(len(kmeans))]
#
# NameError: name 'kmeans' is not defined

# %%
kclusters = 6
boroughs_grouped_clustering = boroughs_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(boroughs_grouped_clustering)

kmeans.labels_
# Out:
# array([0, 5, 0, 0, 0, 5, 0, 0, 3, 3, 5, 0, 3, 0, 0, 3, 5, 5, 4, 5, 3, 3,
#        3, 0, 3, 0, 1, 2, 3, 0, 0, 3, 3, 3, 3, 5, 0, 5], dtype=int32)

# %%
neighborhoods_venues_sorted['Cluster Labels'] = pd.Series(kmeans.labels_)

boroughs_merged = boroughs_df

boroughs_merged = boroughs_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

boroughs_merged.head()
# Out:
#   PostalCode           Borough    Neighbourhood  latitude  longitude  \
# 0        M5A  Downtown Toronto      Regent Park  43.65512  -79.36264
# 1        M7A  Downtown Toronto     Queen's Park  43.66253  -79.39188
# 2        M5B  Downtown Toronto  Garden District  43.65739  -79.37804
# 3        M5C  Downtown Toronto   St. James Town  43.65215  -79.37587
# 4        M4E      East Toronto      The Beaches  43.67709  -79.29547
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop            Restaurant                  Café
# 1           Coffee Shop      Sushi Restaurant   Japanese Restaurant
# 2   Japanese Restaurant           Coffee Shop                  Café
# 3                  Café           Coffee Shop            Restaurant
# 4                   Pub           Coffee Shop        Breakfast Spot
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                Bakery    Italian Restaurant            Beer Store
# 1                  Park                  Café            Restaurant
# 2      Sushi Restaurant             Gastropub    Italian Restaurant
# 3   Japanese Restaurant    Italian Restaurant                Bakery
# 4          Burger Joint                Bakery        Sandwich Place
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                   Pub                  Park         Grocery Store
# 1           Pizza Place             Bookstore  Gym / Fitness Center
# 2            Restaurant        Sandwich Place               Theater
# 3             Gastropub              Beer Bar         Deli / Bodega
# 4                  Park       Thai Restaurant        Ice Cream Shop
#
#   10th Most Common Venue  Cluster Labels
# 0        Thai Restaurant               3
# 1         Sandwich Place               0
# 2                 Bakery               0
# 3                   Park               0
# 4   Caribbean Restaurant               3

# %%
columns = [column for column in boroughs_merged.columns if column.endswith('Venue')]
columns = ['Borough', 'Neighbourhood', 'Cluster Labels'] + columns
boroughs_merged[columns].sort_values(by = 'Cluster Labels', ascending = True)
# Out:
#              Borough                          Neighbourhood  Cluster Labels  \
# 38      East Toronto  Business reply mail Processing Centre               0
# 1   Downtown Toronto                           Queen's Park               0
# 2   Downtown Toronto                        Garden District               0
# 3   Downtown Toronto                         St. James Town               0
# 36  Downtown Toronto                   First Canadian Place               0
# 5   Downtown Toronto                            Berczy Park               0
# 6   Downtown Toronto                     Central Bay Street               0
# 35  Downtown Toronto                         St. James Town               0
# 8   Downtown Toronto                               Richmond               0
# 34  Downtown Toronto                         Stn A PO Boxes               0
# 10  Downtown Toronto                      Harbourfront East               0
# 32  Downtown Toronto                               CN Tower               0
# 13  Downtown Toronto                Toronto Dominion Centre               0
# 37  Downtown Toronto                   Church and Wellesley               0
# 16  Downtown Toronto                         Commerce Court               0
# 33  Downtown Toronto                               Rosedale               1
# 19   Central Toronto                               Roselawn               2
# 17      East Toronto                        Studio District               3
# 4       East Toronto                            The Beaches               3
# 31   Central Toronto                        Summerhill West               3
# 29   Central Toronto                             Moore Park               3
# 28      West Toronto                              Runnymede               3
# 26   Central Toronto                             Davisville               3
# 25      West Toronto                               Parkdale               3
# 0   Downtown Toronto                            Regent Park               3
# 23   Central Toronto                     North Toronto West               3
# 22      West Toronto                              High Park               3
# 21   Central Toronto               Forest Hill North & West               3
# 20   Central Toronto                       Davisville North               3
# 24   Central Toronto                              The Annex               3
# 18   Central Toronto                          Lawrence Park               4
# 15      East Toronto                           India Bazaar               5
# 30  Downtown Toronto                      Kensington Market               5
# 14      West Toronto                               Brockton               5
# 12      East Toronto                      The Danforth West               5
# 11      West Toronto                        Little Portugal               5
# 9       West Toronto                               Dufferin               5
# 7   Downtown Toronto                               Christie               5
# 27  Downtown Toronto                  University of Toronto               5
#
#    1st Most Common Venue 2nd Most Common Venue          3rd Most Common Venue  \
# 38           Coffee Shop                  Café                     Restaurant
# 1            Coffee Shop      Sushi Restaurant            Japanese Restaurant
# 2    Japanese Restaurant           Coffee Shop                           Café
# 3                   Café           Coffee Shop                     Restaurant
# 36                  Café           Coffee Shop                     Restaurant
# 5            Coffee Shop                  Café             Italian Restaurant
# 6            Coffee Shop   Japanese Restaurant                           Café
# 35                  Café           Coffee Shop                     Restaurant
# 8            Coffee Shop                  Café                     Restaurant
# 34           Coffee Shop                  Café                     Restaurant
# 10                  Café           Coffee Shop                           Park
# 32           Coffee Shop                  Café                           Park
# 13                  Café   Japanese Restaurant                    Coffee Shop
# 37   Japanese Restaurant           Coffee Shop                           Park
# 16           Coffee Shop                  Café            Japanese Restaurant
# 33                  Park                 Trail                     Playground
# 19              Pharmacy            Playground                   Skating Rink
# 17           Coffee Shop           Pizza Place                         Bakery
# 4                    Pub           Coffee Shop                 Breakfast Spot
# 31           Coffee Shop                  Café                           Park
# 29           Coffee Shop         Grocery Store             Italian Restaurant
# 28           Coffee Shop                  Café                            Pub
# 26           Coffee Shop      Sushi Restaurant             Italian Restaurant
# 25           Coffee Shop                  Café                  Grocery Store
# 0            Coffee Shop            Restaurant                           Café
# 23           Coffee Shop    Italian Restaurant            Sporting Goods Shop
# 22                   Bar                  Café                    Coffee Shop
# 21                  Park           Coffee Shop             Italian Restaurant
# 20           Coffee Shop    Italian Restaurant                    Pizza Place
# 24           Coffee Shop    Italian Restaurant                           Café
# 18                  Café                  Park                   College Quad
# 15     Indian Restaurant           Coffee Shop                           Park
# 30                  Café           Coffee Shop  Vegetarian / Vegan Restaurant
# 14                  Café           Coffee Shop                            Bar
# 12      Greek Restaurant           Coffee Shop                           Café
# 11                  Café    Italian Restaurant                    Pizza Place
# 9                    Bar                Bakery                    Coffee Shop
# 7      Korean Restaurant           Coffee Shop                           Café
# 27                  Café                Bakery  Vegetarian / Vegan Restaurant
#
#    4th Most Common Venue          5th Most Common Venue  \
# 38                 Hotel                            Gym
# 1                   Park                           Café
# 2       Sushi Restaurant                      Gastropub
# 3    Japanese Restaurant             Italian Restaurant
# 36   Japanese Restaurant                            Gym
# 5             Restaurant            Japanese Restaurant
# 6       Sushi Restaurant                     Restaurant
# 35   Japanese Restaurant             Italian Restaurant
# 8    Japanese Restaurant                            Gym
# 34                 Hotel                            Gym
# 10            Restaurant                   Cocktail Bar
# 32           Yoga Studio           Gym / Fitness Center
# 13                 Hotel                     Restaurant
# 37      Sushi Restaurant       Mediterranean Restaurant
# 16            Restaurant               Sushi Restaurant
# 33           Candy Store                  Grocery Store
# 19      Asian Restaurant                          Trail
# 17  Fast Food Restaurant                            Bar
# 4           Burger Joint                         Bakery
# 31                  Bank                Thai Restaurant
# 29                   Gym                           Park
# 28           Pizza Place              Food & Drink Shop
# 26           Pizza Place              Indian Restaurant
# 25      Sushi Restaurant                         Bakery
# 0                 Bakery             Italian Restaurant
# 23       Thai Restaurant                            Gym
# 22      Sushi Restaurant                            Gym
# 21                  Café                       Pharmacy
# 20                  Café               Sushi Restaurant
# 24                   Gym                 Sandwich Place
# 18             Bookstore           Gym / Fitness Center
# 15  Fast Food Restaurant                            Pub
# 30           Art Gallery                    Yoga Studio
# 14                Bakery                 Sandwich Place
# 12                  Bank                            Pub
# 11                Bakery  Vegetarian / Vegan Restaurant
# 9                   Café                           Park
# 7          Grocery Store            Japanese Restaurant
# 27        Sandwich Place                    Coffee Shop
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 38          Japanese Restaurant             Gastropub        Clothing Store
# 1                    Restaurant           Pizza Place             Bookstore
# 2            Italian Restaurant            Restaurant        Sandwich Place
# 3                        Bakery             Gastropub              Beer Bar
# 36                Deli / Bodega      Sushi Restaurant          Cocktail Bar
# 5                          Park          Cocktail Bar    Seafood Restaurant
# 6                Clothing Store                Bakery                 Hotel
# 35                       Bakery             Gastropub              Beer Bar
# 8                         Hotel        Clothing Store      Sushi Restaurant
# 34          Japanese Restaurant             Gastropub        Clothing Store
# 10                Deli / Bodega                 Hotel                   Gym
# 32            French Restaurant                   Spa                 Diner
# 13                          Gym                  Park         Deli / Bodega
# 37                         Café                 Diner            Restaurant
# 16                          Gym             Gastropub              Beer Bar
# 33                 Optical Shop          Noodle House             Nightclub
# 19                         Café                  Bank           Music Store
# 17          American Restaurant                 Diner    Italian Restaurant
# 4                Sandwich Place                  Park       Thai Restaurant
# 31             Sushi Restaurant         Grocery Store    Italian Restaurant
# 29                  Pizza Place                  Bank       Thai Restaurant
# 28             Sushi Restaurant                  Bank                Bakery
# 26                         Café                Bakery                  Bank
# 25  Eastern European Restaurant       Thai Restaurant            Restaurant
# 0                    Beer Store                   Pub                  Park
# 23                       Bakery                  Café                  Park
# 22                          Pub                  Park         Grocery Store
# 21                         Bank      Sushi Restaurant        Ice Cream Shop
# 20         Fast Food Restaurant       Thai Restaurant                 Diner
# 24                Grocery Store                   Pub           Pizza Place
# 18                  Coffee Shop                 Trail           College Gym
# 15                   Restaurant         Grocery Store        Sandwich Place
# 30          Arts & Crafts Store                Bakery                   Gym
# 14       Furniture / Home Store            Restaurant    Italian Restaurant
# 12           Italian Restaurant  Fast Food Restaurant        Ice Cream Shop
# 11             Asian Restaurant          Cocktail Bar           Coffee Shop
# 9            Mexican Restaurant    Italian Restaurant         Grocery Store
# 7                           Pub               Theater  Caribbean Restaurant
# 27                     Beer Bar            Restaurant       Thai Restaurant
#
#       9th Most Common Venue      10th Most Common Venue
# 38               Shoe Store                Concert Hall
# 1      Gym / Fitness Center              Sandwich Place
# 2                   Theater                      Bakery
# 3             Deli / Bodega                        Park
# 36                    Hotel          Salon / Barbershop
# 5                       Gym                       Hotel
# 6                       Gym  Modern European Restaurant
# 35            Deli / Bodega                        Park
# 8                    Bakery               Deli / Bodega
# 34               Shoe Store                Concert Hall
# 10      Japanese Restaurant            Sushi Restaurant
# 32       Italian Restaurant                Dessert Shop
# 13             Cocktail Bar            Sushi Restaurant
# 37           Clothing Store                   Gastropub
# 16             Cocktail Bar          Seafood Restaurant
# 33  New American Restaurant                  Nail Salon
# 19             Music School                Optical Shop
# 17                     Café                        Bank
# 4            Ice Cream Shop        Caribbean Restaurant
# 31                      Gym        Gym / Fitness Center
# 29               Bagel Shop                   Gastropub
# 28       Italian Restaurant                         Gym
# 26               Restaurant                         Gym
# 25                 Pharmacy                 Pizza Place
# 0             Grocery Store             Thai Restaurant
# 23               Restaurant                  Playground
# 22       Mexican Restaurant             Thai Restaurant
# 21  Fruit & Vegetable Store               Grocery Store
# 20              Supermarket              Clothing Store
# 24                 Pharmacy             Thai Restaurant
# 18                 Bus Line                  Restaurant
# 15            Burrito Place             Harbor / Marina
# 30             Burger Joint            Sushi Restaurant
# 14           Breakfast Spot                Cocktail Bar
# 12                   Bakery                     Theater
# 11               Restaurant                         Bar
# 9                  Pharmacy                        Bank
# 7          Sushi Restaurant              Sandwich Place
# 27            Grocery Store                         Bar

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium # map rendering library

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(boroughs_merged['latitude'], boroughs_merged['longitude'], boroughs_merged['Neighbourhood'], boroughs_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color='black',
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f6d041c4acf444381eaa7de1339efc2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f6d041c4acf444381eaa7de1339efc2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f6d041c4acf444381eaa7de1339efc2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f6d041c4acf444381eaa7de1339efc2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.65238435%2C%20-79.38356765%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
cluster_0 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 0, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_0
# Out:
#                             Neighbourhood 1st Most Common Venue  \
# 1                            Queen's Park           Coffee Shop
# 2                         Garden District   Japanese Restaurant
# 3                          St. James Town                  Café
# 5                             Berczy Park           Coffee Shop
# 6                      Central Bay Street           Coffee Shop
# 8                                Richmond           Coffee Shop
# 10                      Harbourfront East                  Café
# 13                Toronto Dominion Centre                  Café
# 16                         Commerce Court           Coffee Shop
# 32                               CN Tower           Coffee Shop
# 34                         Stn A PO Boxes           Coffee Shop
# 35                         St. James Town                  Café
# 36                   First Canadian Place                  Café
# 37                   Church and Wellesley   Japanese Restaurant
# 38  Business reply mail Processing Centre           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1       Sushi Restaurant   Japanese Restaurant                  Park
# 2            Coffee Shop                  Café      Sushi Restaurant
# 3            Coffee Shop            Restaurant   Japanese Restaurant
# 5                   Café    Italian Restaurant            Restaurant
# 6    Japanese Restaurant                  Café      Sushi Restaurant
# 8                   Café            Restaurant   Japanese Restaurant
# 10           Coffee Shop                  Park            Restaurant
# 13   Japanese Restaurant           Coffee Shop                 Hotel
# 16                  Café   Japanese Restaurant            Restaurant
# 32                  Café                  Park           Yoga Studio
# 34                  Café            Restaurant                 Hotel
# 35           Coffee Shop            Restaurant   Japanese Restaurant
# 36           Coffee Shop            Restaurant   Japanese Restaurant
# 37           Coffee Shop                  Park      Sushi Restaurant
# 38                  Café            Restaurant                 Hotel
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1                       Café            Restaurant           Pizza Place
# 2                  Gastropub    Italian Restaurant            Restaurant
# 3         Italian Restaurant                Bakery             Gastropub
# 5        Japanese Restaurant                  Park          Cocktail Bar
# 6                 Restaurant        Clothing Store                Bakery
# 8                        Gym                 Hotel        Clothing Store
# 10              Cocktail Bar         Deli / Bodega                 Hotel
# 13                Restaurant                   Gym                  Park
# 16          Sushi Restaurant                   Gym             Gastropub
# 32      Gym / Fitness Center     French Restaurant                   Spa
# 34                       Gym   Japanese Restaurant             Gastropub
# 35        Italian Restaurant                Bakery             Gastropub
# 36                       Gym         Deli / Bodega      Sushi Restaurant
# 37  Mediterranean Restaurant                  Café                 Diner
# 38                       Gym   Japanese Restaurant             Gastropub
#
#    8th Most Common Venue 9th Most Common Venue      10th Most Common Venue  \
# 1              Bookstore  Gym / Fitness Center              Sandwich Place
# 2         Sandwich Place               Theater                      Bakery
# 3               Beer Bar         Deli / Bodega                        Park
# 5     Seafood Restaurant                   Gym                       Hotel
# 6                  Hotel                   Gym  Modern European Restaurant
# 8       Sushi Restaurant                Bakery               Deli / Bodega
# 10                   Gym   Japanese Restaurant            Sushi Restaurant
# 13         Deli / Bodega          Cocktail Bar            Sushi Restaurant
# 16              Beer Bar          Cocktail Bar          Seafood Restaurant
# 32                 Diner    Italian Restaurant                Dessert Shop
# 34        Clothing Store            Shoe Store                Concert Hall
# 35              Beer Bar         Deli / Bodega                        Park
# 36          Cocktail Bar                 Hotel          Salon / Barbershop
# 37            Restaurant        Clothing Store                   Gastropub
# 38        Clothing Store            Shoe Store                Concert Hall
#
#     Cluster Labels
# 1                0
# 2                0
# 3                0
# 5                0
# 6                0
# 8                0
# 10               0
# 13               0
# 16               0
# 32               0
# 34               0
# 35               0
# 36               0
# 37               0
# 38               0

# %%
cluster_1 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 1, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_1
# Out:
#    Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 33      Rosedale                  Park                 Trail
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 33            Playground           Candy Store         Grocery Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 33          Optical Shop          Noodle House             Nightclub
#
#       9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 33  New American Restaurant             Nail Salon               1

# %%
cluster_2 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 2, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_2
# Out:
#    Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 19      Roselawn              Pharmacy            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19          Skating Rink      Asian Restaurant                 Trail
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19                  Café                  Bank           Music Store
#
#    9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 19          Music School           Optical Shop               2

# %%
cluster_3 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 3, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_3
# Out:
#                Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 0                Regent Park           Coffee Shop            Restaurant
# 4                The Beaches                   Pub           Coffee Shop
# 17           Studio District           Coffee Shop           Pizza Place
# 20          Davisville North           Coffee Shop    Italian Restaurant
# 21  Forest Hill North & West                  Park           Coffee Shop
# 22                 High Park                   Bar                  Café
# 23        North Toronto West           Coffee Shop    Italian Restaurant
# 24                 The Annex           Coffee Shop    Italian Restaurant
# 25                  Parkdale           Coffee Shop                  Café
# 26                Davisville           Coffee Shop      Sushi Restaurant
# 28                 Runnymede           Coffee Shop                  Café
# 29                Moore Park           Coffee Shop         Grocery Store
# 31           Summerhill West           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                   Café                Bakery    Italian Restaurant
# 4         Breakfast Spot          Burger Joint                Bakery
# 17                Bakery  Fast Food Restaurant                   Bar
# 20           Pizza Place                  Café      Sushi Restaurant
# 21    Italian Restaurant                  Café              Pharmacy
# 22           Coffee Shop      Sushi Restaurant                   Gym
# 23   Sporting Goods Shop       Thai Restaurant                   Gym
# 24                  Café                   Gym        Sandwich Place
# 25         Grocery Store      Sushi Restaurant                Bakery
# 26    Italian Restaurant           Pizza Place     Indian Restaurant
# 28                   Pub           Pizza Place     Food & Drink Shop
# 29    Italian Restaurant                   Gym                  Park
# 31                  Park                  Bank       Thai Restaurant
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Beer Store                   Pub                  Park
# 4                Sandwich Place                  Park       Thai Restaurant
# 17          American Restaurant                 Diner    Italian Restaurant
# 20         Fast Food Restaurant       Thai Restaurant                 Diner
# 21                         Bank      Sushi Restaurant        Ice Cream Shop
# 22                          Pub                  Park         Grocery Store
# 23                       Bakery                  Café                  Park
# 24                Grocery Store                   Pub           Pizza Place
# 25  Eastern European Restaurant       Thai Restaurant            Restaurant
# 26                         Café                Bakery                  Bank
# 28             Sushi Restaurant                  Bank                Bakery
# 29                  Pizza Place                  Bank       Thai Restaurant
# 31             Sushi Restaurant         Grocery Store    Italian Restaurant
#
#       9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 0             Grocery Store        Thai Restaurant               3
# 4            Ice Cream Shop   Caribbean Restaurant               3
# 17                     Café                   Bank               3
# 20              Supermarket         Clothing Store               3
# 21  Fruit & Vegetable Store          Grocery Store               3
# 22       Mexican Restaurant        Thai Restaurant               3
# 23               Restaurant             Playground               3
# 24                 Pharmacy        Thai Restaurant               3
# 25                 Pharmacy            Pizza Place               3
# 26               Restaurant                    Gym               3
# 28       Italian Restaurant                    Gym               3
# 29               Bagel Shop              Gastropub               3
# 31                      Gym   Gym / Fitness Center               3

# %%
cluster_4 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 4, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_4
# Out:
#     Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 18  Lawrence Park                  Café                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18          College Quad             Bookstore  Gym / Fitness Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18           Coffee Shop                 Trail           College Gym
#
#    9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 18              Bus Line             Restaurant               4

# %%
cluster_5 = boroughs_merged.loc[boroughs_merged['Cluster Labels'] == 5, boroughs_merged.columns[[2] + list(range(5, boroughs_merged.shape[1]))]]
cluster_5
# Out:
#             Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 7                Christie     Korean Restaurant           Coffee Shop
# 9                Dufferin                   Bar                Bakery
# 11        Little Portugal                  Café    Italian Restaurant
# 12      The Danforth West      Greek Restaurant           Coffee Shop
# 14               Brockton                  Café           Coffee Shop
# 15           India Bazaar     Indian Restaurant           Coffee Shop
# 27  University of Toronto                  Café                Bakery
# 30      Kensington Market                  Café           Coffee Shop
#
#             3rd Most Common Venue 4th Most Common Venue  \
# 7                            Café         Grocery Store
# 9                     Coffee Shop                  Café
# 11                    Pizza Place                Bakery
# 12                           Café                  Bank
# 14                            Bar                Bakery
# 15                           Park  Fast Food Restaurant
# 27  Vegetarian / Vegan Restaurant        Sandwich Place
# 30  Vegetarian / Vegan Restaurant           Art Gallery
#
#             5th Most Common Venue   6th Most Common Venue  \
# 7             Japanese Restaurant                     Pub
# 9                            Park      Mexican Restaurant
# 11  Vegetarian / Vegan Restaurant        Asian Restaurant
# 12                            Pub      Italian Restaurant
# 14                 Sandwich Place  Furniture / Home Store
# 15                            Pub              Restaurant
# 27                    Coffee Shop                Beer Bar
# 30                    Yoga Studio     Arts & Crafts Store
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 7                Theater  Caribbean Restaurant      Sushi Restaurant
# 9     Italian Restaurant         Grocery Store              Pharmacy
# 11          Cocktail Bar           Coffee Shop            Restaurant
# 12  Fast Food Restaurant        Ice Cream Shop                Bakery
# 14            Restaurant    Italian Restaurant        Breakfast Spot
# 15         Grocery Store        Sandwich Place         Burrito Place
# 27            Restaurant       Thai Restaurant         Grocery Store
# 30                Bakery                   Gym          Burger Joint
#
#    10th Most Common Venue  Cluster Labels
# 7          Sandwich Place               5
# 9                    Bank               5
# 11                    Bar               5
# 12                Theater               5
# 14           Cocktail Bar               5
# 15        Harbor / Marina               5
# 27                    Bar               5
# 30       Sushi Restaurant               5
